# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-ada535d7-94c4-43c9-8ba8-0dcbb3965dfb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ada535d7-94c4-43c9-8ba8-0dcbb3965dfb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import numpy as np
import pandas as pd
df = pd.read_csv("/content/placement.csv")
df
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 0            0   6.8  123.0          1
# 1            1   5.9  106.0          0
# 2            2   5.3  121.0          0
# 3            3   7.4  132.0          1
# 4            4   5.8  142.0          0
# ..         ...   ...    ...        ...
# 95          95   4.3  200.0          0
# 96          96   4.4   42.0          0
# 97          97   6.7  182.0          1
# 98          98   6.3  103.0          1
# 99          99   6.2  113.0          1
#
# [100 rows x 4 columns]

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df = df.iloc[:,1:] #[rows,cols]
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement']) #c= color

# %%
X = df.iloc[:,0:2]
Y = df.iloc[:,-1]

# %%
X #independent variable
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
Y #dependent variable
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size = 0.1)
# splited into x = training set , x = test set(10)
            #  y = training set , y = test set(10)

# %%
x_train   #[x (train) = y(train)], [ x_test  = y_test]
# Out:
#     cgpa     iq
# 33   6.0  149.0
# 39   4.6  146.0
# 36   5.7  140.0
# 67   5.0  118.0
# 24   4.7  121.0
# ..   ...    ...
# 53   8.3  168.0
# 43   6.8  141.0
# 99   6.2  113.0
# 31   3.9  109.0
# 82   6.5   37.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 33    0
# 39    0
# 36    0
# 67    0
# 24    0
#      ..
# 53    1
# 43    1
# 99    1
# 31    0
# 82    1
# Name: placement, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
x_train = scaler.fit_transform(x_train)  #fit is used to understand and transform the data in the range of -1 to 1

# %%
x_train
# Out:
# array([[-0.01352696,  0.65305725],
#        [-1.23095292,  0.57859549],
#        [-0.27440395,  0.42967196],
#        [-0.88311693, -0.11638098],
#        [-1.14399393, -0.04191922],
#        [ 1.37781701, -0.83617803],
#        [-0.88311693, -0.78653686],
#        [-1.14399393, -1.75453979],
#        [ 0.42126803,  0.18146608],
#        [ 0.68214503, -0.81135745],
#        [ 0.50822703,  0.38003078],
#        [ 1.29085801,  0.18146608],
#        [-0.79615793,  1.32321313],
#        [ 0.85606302, -0.26530451],
#        [-0.97007593, -0.0667398 ],
#        [-0.27440395,  0.50413372],
#        [ 1.11694001, -1.80418097],
#        [-0.97007593,  0.80198078],
#        [ 1.725653  , -1.08438391],
#        [-0.10048595, -0.41422804],
#        [ 1.11694001,  0.35521019],
#        [-0.70919894, -0.31494568],
#        [-0.79615793,  0.1318249 ],
#        [-0.27440395,  0.23110725],
#        [-0.53528094, -0.38940745],
#        [ 0.07343204, -1.03474274],
#        [ 0.50822703, -0.0667398 ],
# ...

# %%
x_test= scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-0.88311693, -0.78653686],
#        [ 0.59518603,  1.47213666],
#        [-0.53528094,  0.30556902],
#        [-0.97007593,  1.81962489],
#        [-0.97007593,  0.28074843],
#        [-0.97007593, -0.0667398 ],
#        [-0.88311693, -1.48151332],
#        [-0.97007593,  0.80198078],
#        [ 1.29085801,  0.18146608],
#        [-0.53528094, -0.21566333]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf = LogisticRegression()

# %%
# model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = clf.predict(x_test)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
y_test
# Out:
# 25    0
# 97    1
# 49    0
# 80    0
# 40    0
# 22    0
# 7     0
# 76    0
# 83    1
# 41    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X=x_train.values, y=y_train.values, clf=clf, legend=2)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
