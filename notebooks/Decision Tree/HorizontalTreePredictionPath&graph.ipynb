# %%
from sklearn.datasets import load_iris
from sklearn.tree import DecisionTreeClassifier

iris = load_iris()

X = iris.data
y = iris.target

clf = DecisionTreeClassifier(max_depth=3,random_state=42)
clf.fit(X,y)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=42)

# %% [markdown]
# ### Normal Decision Tree

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

plt.figure(figsize=(15,8))

plot_tree(clf,feature_names=iris.feature_names,
          class_names=iris.target_names,
          filled=True,rounded=True)
plt.show()

# %%
# !pip install dtreeviz
# Out:
# Collecting dtreeviz
#   Downloading dtreeviz-2.3.2-py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: graphviz>=0.9 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from dtreeviz) (0.21)
# Requirement already satisfied: pandas in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from dtreeviz) (2.3.3)
# Requirement already satisfied: numpy in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from dtreeviz) (2.3.5)
# Requirement already satisfied: scikit-learn in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from dtreeviz) (1.9.0)
# Requirement already satisfied: matplotlib in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from dtreeviz) (3.11.1)
# Collecting colour (from dtreeviz)
#   Downloading colour-0.1.5-py2.py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from matplotlib->dtreeviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from matplotlib->dtreeviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.28.2 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from matplotlib->dtreeviz) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from matplotlib->dtreeviz) (1.5.0)
# Requirement already satisfied: packaging>=20.0 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from matplotlib->dtreeviz) (26.2)
# Requirement already satisfied: pillow>=9 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from matplotlib->dtreeviz) (12.2.0)
# Requirement already satisfied: pyparsing>=3 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from matplotlib->dtreeviz) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from matplotlib->dtreeviz) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from python-dateutil>=2.7->matplotlib->dtreeviz) (1.17.0)
# Requirement already satisfied: pytz>=2020.1 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from pandas->dtreeviz) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from pandas->dtreeviz) (2026.2)
# Requirement already satisfied: scipy>=1.10.0 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from scikit-learn->dtreeviz) (1.16.3)
# Requirement already satisfied: joblib>=1.4.0 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from scikit-learn->dtreeviz) (1.5.3)
# Requirement already satisfied: narwhals>=2.0.1 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from scikit-learn->dtreeviz) (2.22.1)
# Requirement already satisfied: threadpoolctl>=3.5.0 in C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages (from scikit-learn->dtreeviz) (3.6.0)
# Downloading dtreeviz-2.3.2-py3-none-any.whl (102 kB)
# Downloading colour-0.1.5-py2.py3-none-any.whl (23 kB)
# Installing collected packages: colour, dtreeviz
#
#    -------------------- ------------------- 1/2 [dtreeviz]
#    -------------------- ------------------- 1/2 [dtreeviz]
#    -------------------- ------------------- 1/2 [dtreeviz]
#    -------------------- ------------------- 1/2 [dtreeviz]
#    -------------------- ------------------- 1/2 [dtreeviz]
#    -------------------- ------------------- 1/2 [dtreeviz]
#    ---------------------------------------- 2/2 [dtreeviz]
#
# Successfully installed colour-0.1.5 dtreeviz-2.3.2
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~umpy (C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages)
#
# [notice] A new release of pip is available: 26.1.2 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from dtreeviz import model

# %%
import dtreeviz
print(dtreeviz.__version__)

from sklearn.datasets import *
from dtreeviz.trees import *
from IPython.display import Image, display_svg, SVG
# Out:
# 2.3.2

# %%
viz = model(clf,X,y,feature_names=iris.feature_names,
            target_name="species",
            class_names=list(iris.target_names)
           )
viz.view(orientation="LR")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\Machine-Learning\.venv\Lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File C:\Program Files\Python313\Lib\subprocess.py:554, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     552     kwargs['stderr'] = PIPE
# --> 554 with Popen(*popenargs, **kwargs) as process:
#     555     try:
#
# File C:\Program Files\Python313\Lib\subprocess.py:1039, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
#    1036             self.stderr = io.TextIOWrapper(self.stderr,
#    1037                     encoding=encoding, errors=errors)
# -> 1039     self._execute_child(args, executable, preexec_fn, close_fds,
#    1040                         pass_fds, cwd, env,
#    1041                         startupinfo, creationflags, shell,
#    1042                         p2cread, p2cwrite,
#    1043                         c2pread, c2pwrite,
#    1044                         errread, errwrite,
#    1045                         restore_signals,
#    1046                         gid, gids, uid, umask,
#    1047                         start_new_session, process_group)
#    1048 except:
#    1049     # Cleanup if the child failed starting.
#
# File C:\Program Files\Python313\Lib\subprocess.py:1554, in Popen._execute_child(self, args, executable, preexec_fn, close_fds, pass_fds, cwd, env, startupinfo, creationflags, shell, p2cread, p2cwrite, c2pread, c2pwrite, errread, errwrite, unused_restore_signals, unused_gid, unused_gids, unused_uid, unused_umask, unused_start_new_session, unused_process_group)
#    1553 try:
# -> 1554     hp, ht, pid, tid = _winapi.CreateProcess(executable, args,
#    1555                              # no special security
#    1556                              None, None,
#    1557                              int(not close_fds),
#    1558                              creationflags,
#    1559                              env,
#    1560                              cwd,
#    1561                              startupinfo)
#    1562 finally:
#    1563     # Child is launched. Close the parent's copy of those pipe
#    1564     # handles that only the child should have open.  You need
#    (...)   1567     # pipe will not close when the child process exits and the
#    1568     # ReadFile will hang.
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified
#
# The above exception was the direct cause of the following exception:
#
# ExecutableNotFound                        Traceback (most recent call last)
# File ~\Machine-Learning\.venv\Lib\site-packages\dtreeviz\utils.py:242, in DTreeVizRender._repr_svg_(self)
#     241 def _repr_svg_(self):
# --> 242     return self.svg()
#
# File ~\Machine-Learning\.venv\Lib\site-packages\dtreeviz\utils.py:246, in DTreeVizRender.svg(self)
#     244 def svg(self):
#     245     """Render tree as svg and return svg text."""
# --> 246     svgfilename = self.save_svg()
#     247     with open(svgfilename, encoding='UTF-8') as f:
#     248         svg = f.read()
#
# File ~\Machine-Learning\.venv\Lib\site-packages\dtreeviz\utils.py:266, in DTreeVizRender.save_svg(self)
#     264 tmp = tempfile.gettempdir()
#     265 svgfilename = os.path.join(tmp, f"DTreeViz_{os.getpid()}.svg")
# --> 266 self.save(svgfilename)
#     267 return svgfilename
#
# File ~\Machine-Learning\.venv\Lib\site-packages\dtreeviz\utils.py:294, in DTreeVizRender.save(self, filename)
#     292     graphviz.backend.run(cmd, capture_output=True, check=True, quiet=False)
#     293 else:
# --> 294     graphviz.backend.execute.run_check(cmd, capture_output=True, check=True, quiet=False)
#     296 if filename.endswith(".svg"):
#     297     # now merge in referenced SVG images to make all-in-one file
#     298     with open(filename, encoding='UTF-8') as f:
#
# File ~\Machine-Learning\.venv\Lib\site-packages\graphviz\backend\execute.py:81, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      79 except OSError as e:
#      80     if e.errno == errno.ENOENT:
# ---> 81         raise ExecutableNotFound(cmd) from e
#      82     raise
#      84 if not quiet and proc.stderr:
#
# ExecutableNotFound: failed to execute 'dot', make sure the Graphviz executables are on your systems' PATH

# %%
viz = dtreeviz(clf, 
               X,
               y,
               feature_names=iris.feature_names, 
               class_names=["setosa", "versicolor", "virginica"])
viz
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 viz = dtreeviz(clf,
#       2                X,
#       3                y,
#       4                feature_names=iris.feature_names,
#
# TypeError: 'module' object is not callable. Did you mean: 'dtreeviz.dtreeviz(...)'?
