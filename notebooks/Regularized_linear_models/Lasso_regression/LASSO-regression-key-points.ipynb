# %% [markdown]
# ## How are coefficients affected?

# %%
from sklearn.datasets import load_diabetes

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
data = load_diabetes()

df = pd.DataFrame(data.data,columns = data.feature_names)
df['Target'] = data.target
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  Target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
X_train,X_test,y_train,y_test = train_test_split(data.data,data.target,test_size= 0.2, random_state=2)

# %%
coefs = []
r2_scores = []

for i in [0,0.1,1,10]:
    reg = Lasso(alpha = i)
    reg.fit(X_train,y_train)

    coefs.append(reg.coef_.tolist())
    y_pred = reg.predict(X_test)
    r2_scores.append(r2_score(y_test,y_pred))
# Out:
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)

# %%
plt.figure(figsize=(14,9))
plt.subplot(221)
plt.bar(data.feature_names,coefs[0])
plt.title('Alpha = 0 ,r2_score = {}'.format(round(r2_scores[0],2)))

plt.subplot(222)
plt.bar(data.feature_names,coefs[1])
plt.title('Alpha = 0.1 ,r2_score = {}'.format(round(r2_scores[1],2)))

plt.subplot(223)
plt.bar(data.feature_names,coefs[2])
plt.title('Alpha = 1 ,r2_score = {}'.format(round(r2_scores[2],2)))

plt.subplot(224)
plt.bar(data.feature_names,coefs[3])
plt.title('Alpha = 10 ,r2_score = {}'.format(round(r2_scores[3],2)))

plt.show()

# %% [markdown]
# ## Higher coeficients are affected more

# %%
alphas =[0,0.0001,0.001,0.01,0.1,1,10,100,1000,10000]

coefs= []

for i in alphas:
    reg = Lasso(alpha =i)
    reg.fit(X_train,y_train)

    coefs.append(reg.coef_.tolist())
# Out:
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)

# %%
input_array = np.array(coefs)

coef_df = pd.DataFrame(input_array,columns = data.feature_names)
coef_df['alpha'] = alphas
coef_df.set_index('alpha')
# Out:
#                  age         sex         bmi          bp          s1  \
# alpha
# 0.0000     -9.157778 -205.412964  516.781112  340.597980 -890.752436
# 0.0001     -9.069064 -205.329406  516.789418  340.532379 -888.660904
# 0.0010     -8.262770 -204.205364  517.650073  339.743901 -826.663603
# 0.0100     -1.359721 -192.937180  526.356514  332.641101 -430.226975
# 0.1000      0.000000 -113.969928  526.744396  292.628472  -82.693681
# 1.0000      0.000000    0.000000  363.885742   27.273163    0.000000
# 10.0000     0.000000    0.000000    0.000000    0.000000    0.000000
# 100.0000    0.000000    0.000000    0.000000    0.000000    0.000000
# 1000.0000   0.000000    0.000000    0.000000    0.000000    0.000000
# 10000.0000  0.000000    0.000000    0.000000    0.000000    0.000000
#
#                     s2          s3          s4          s5         s6
# alpha
# 0.0000      557.464984  151.759437  126.112388  859.350316  52.418059
# 0.0001      555.958584  150.593655  125.450143  858.645541  52.380294
# 0.0010      508.617395  120.908607  113.921773  836.320753  52.012849
# 0.0100      191.295480  -44.034913   68.988987  688.396028  47.940616
# 0.1000       -0.000000 -152.685338    0.000000  551.080291   7.170992
# 1.0000        0.000000   -0.000000    0.000000  336.137262   0.000000
# 10.0000       0.000000    0.000000    0.000000    0.000000   0.000000
# 100.0000      0.000000    0.000000    0.000000    0.000000   0.000000
# 1000.0000     0.000000    0.000000    0.000000    0.000000   0.000000
# 10000.0000    0.000000    0.000000    0.000000    0.000000   0.000000

# %%
alphas = [0,0.0001,0.0005,0.001,0.005,0.1,0.5,1,5,10]

coefs = []

for i in alphas:
    reg = Lasso(alpha=i)
    reg.fit(X_train,y_train)
    
    coefs.append(reg.coef_.tolist())
# Out:
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)

# %%
input_array = np.array(coefs).T

plt.figure(figsize=(15,8))
plt.plot(alphas,np.zeros(len(alphas)),color='black',linewidth=5)
for i in range(input_array.shape[0]):
    plt.plot(alphas,input_array[i],label=data.feature_names[i])
plt.legend()

# %% [markdown]
# ## Impact on Bias and Variance

# %%
m = 100
X = 5 * np.random.rand(m, 1) - 2
y = 0.7 * X ** 2 - 2 * X + 3 + np.random.randn(m, 1)

plt.scatter(X, y)
plt.show()

# %%
X_train,X_test,y_train,y_test = train_test_split(X.reshape(100,1),y.reshape(100),test_size=0.2,random_state=2)

from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=10)

X_train = poly.fit_transform(X_train)
X_test = poly.transform(X_test)
from mlxtend.evaluate import bias_variance_decomp

alphas = np.linspace(0,30,100)

loss = []
bias = []
variance = []

for i in alphas:
    reg = Lasso(alpha=i)
    avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        reg, X_train, y_train, X_test, y_test, 
        loss='mse',
        random_seed=123)
    loss.append(avg_expected_loss)
    bias.append(avg_bias)
    variance.append(avg_var)
# Out:
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.624485e+04, tolerance: 4.641e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.368325e+03, tolerance: 5.108e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.158507e+04, tolerance: 5.228e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.393227e+05, tolerance: 4.967e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.700943e+03, tolerance: 3.125e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.968695e+04, tolerance: 3.958e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.405598e+04, tolerance: 3.462e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.064381e+04, tolerance: 4.932e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.872800e+03, tolerance: 4.453e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.296776e+04, tolerance: 3.788e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.187050e+04, tolerance: 3.640e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.576424e+04, tolerance: 4.919e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.733674e+02, tolerance: 4.476e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.042232e+04, tolerance: 4.653e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.896819e+03, tolerance: 4.535e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.156752e+02, tolerance: 5.681e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.822474e+04, tolerance: 3.921e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.725280e+03, tolerance: 4.138e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.759282e+04, tolerance: 4.748e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.717726e+04, tolerance: 3.830e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.189686e+04, tolerance: 3.257e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.655084e+04, tolerance: 4.979e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.972726e+04, tolerance: 3.955e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.727349e+04, tolerance: 4.621e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.532505e+03, tolerance: 5.446e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.254574e+03, tolerance: 4.105e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.323861e+03, tolerance: 5.308e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.503294e+03, tolerance: 3.336e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.152450e+04, tolerance: 4.521e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.792863e+02, tolerance: 3.437e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.737661e+04, tolerance: 5.745e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.812871e+04, tolerance: 4.253e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.392346e+04, tolerance: 4.414e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.739061e+03, tolerance: 5.285e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.090343e+03, tolerance: 4.703e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.616558e+03, tolerance: 3.007e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.119910e+03, tolerance: 5.020e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.194422e+04, tolerance: 4.932e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.645750e+04, tolerance: 2.731e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.216834e+04, tolerance: 4.164e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.034151e+04, tolerance: 3.866e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.251817e+03, tolerance: 4.294e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.365208e+03, tolerance: 5.016e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.055523e+03, tolerance: 3.751e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.106278e+03, tolerance: 5.017e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.517801e+03, tolerance: 2.958e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.331420e+04, tolerance: 4.679e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.398912e+04, tolerance: 4.345e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.880326e+04, tolerance: 4.389e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.083946e+04, tolerance: 3.599e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.975147e+04, tolerance: 4.305e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.754648e+02, tolerance: 5.125e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.994377e+04, tolerance: 4.886e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.975247e+04, tolerance: 4.911e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.170048e+03, tolerance: 4.914e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.149701e+03, tolerance: 3.030e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.442672e+04, tolerance: 3.677e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.996070e+03, tolerance: 4.380e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.396689e+03, tolerance: 4.642e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 8.173703e+04, tolerance: 3.565e-02
# Linear regression models with a zero l1 penalization strength are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 9.202737e+03, tolerance: 3.020e-02
# ...
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.611672e+01, tolerance: 3.885e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.843537e+01, tolerance: 4.240e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.324336e+01, tolerance: 3.825e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.478748e+01, tolerance: 4.198e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.076480e+01, tolerance: 5.248e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.707623e+01, tolerance: 3.554e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.993835e+01, tolerance: 4.294e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.267697e+01, tolerance: 3.650e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.291449e+01, tolerance: 3.704e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.612211e+01, tolerance: 5.275e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.072659e+01, tolerance: 3.564e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.058345e+01, tolerance: 4.391e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.299422e+01, tolerance: 4.798e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.370641e+01, tolerance: 4.978e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.684081e+01, tolerance: 6.085e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.557160e+01, tolerance: 3.998e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.195207e+01, tolerance: 5.626e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.216921e+01, tolerance: 4.803e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.470885e+01, tolerance: 4.127e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.523675e+01, tolerance: 3.917e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.797959e+01, tolerance: 3.241e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.279059e+01, tolerance: 4.405e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.154151e+01, tolerance: 3.014e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.954857e+01, tolerance: 4.209e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.294272e+01, tolerance: 3.373e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.061554e+00, tolerance: 6.399e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.450869e+01, tolerance: 4.608e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.057871e+01, tolerance: 4.563e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.309605e+01, tolerance: 4.043e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.180474e+01, tolerance: 4.043e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.404195e+01, tolerance: 5.809e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.918202e+01, tolerance: 4.118e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.892398e+01, tolerance: 3.932e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.863496e+01, tolerance: 3.474e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.579759e+01, tolerance: 4.726e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.792555e+01, tolerance: 3.129e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.262447e+01, tolerance: 5.658e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.161052e+01, tolerance: 3.348e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.392003e+01, tolerance: 4.390e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.586568e+01, tolerance: 4.145e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.352081e+01, tolerance: 4.020e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 7.792276e+01, tolerance: 4.898e-02
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\KESHAV\Machine-Learning\.venv\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:840: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.992660e+01, tolerance: 5.060e-02
#   model = cd_fast.enet_coordinate_descent(
