# %% [markdown]
# https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html
#
# handing the read_csv file before importing

# %% [markdown]
# <h2> 1. Importing pandas and opening local csv file </h2>

# %%
import pandas as pd
df = pd.read_csv('aug_train.csv', index_col = 'enrollee_id')
df
# Out:
#                  city  city_development_index gender      relevent_experience  \
# enrollee_id
# 8949         city_103                   0.920   Male  Has relevent experience
# 29725         city_40                   0.776   Male   No relevent experience
# 11561         city_21                   0.624    NaN   No relevent experience
# 33241        city_115                   0.789    NaN   No relevent experience
# 666          city_162                   0.767   Male  Has relevent experience
# ...               ...                     ...    ...                      ...
# 7386         city_173                   0.878   Male   No relevent experience
# 31398        city_103                   0.920   Male  Has relevent experience
# 24576        city_103                   0.920   Male  Has relevent experience
# 5756          city_65                   0.802   Male  Has relevent experience
# 23834         city_67                   0.855    NaN   No relevent experience
#
# ...

# %% [markdown]
# <h2> 2. Opening a csv file from an url </h2>

# %%
import requests
from io import StringIO

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:66.0) Gecko/20100101 Firefox/66.0"}
req = requests.get(url, headers = headers)
data = StringIO(req.text)

df= pd.read_csv(data)
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# <h2>3. sep parameter </h2>
# initially the pd.read_csv reads the comma ',' seperated values suppose if there is any tab seperated values then

# %%
pd.read_csv('movie_titles_metadata.tsv')
# Out:
#     m0\t10 things i hate about you\t1999\t6.90\t62847\t['comedy' 'romance']
# 0    m1\t1492: conquest of paradise\t1992\t6.20\t10...
# 1    m2\t15 minutes\t2001\t6.10\t25854\t['action' '...
# 2    m3\t2001: a space odyssey\t1968\t8.40\t163227\...
# 3    m4\t48 hrs.\t1982\t6.90\t22289\t['action' 'com...
# 4    m5\tthe fifth element\t1997\t7.50\t133756\t['a...
# ..                                                 ...
# 611  m612\twatchmen\t2009\t7.80\t135229\t['action' ...
# 612  m613\txxx\t2002\t5.60\t53505\t['action' 'adven...
# 613  m614\tx-men\t2000\t7.40\t122149\t['action' 'sc...
# 614  m615\tyoung frankenstein\t1974\t8.00\t57618\t[...
# 615  m616\tzulu dawn\t1979\t6.40\t1911\t['action' '...
#
# [616 rows x 1 columns]

# %%
#  after using sep parameter 
# and u may see that the first row should be the name but it is the content row here so we may use the nameing to identify them before reading
pd.read_csv('movie_titles_metadata.tsv' , sep = '\t', names = ['Sno.', 'Name', 'Release_Date', 'Rating', 'Views', 'Genes'], index_col = 'Sno.')
# Out:
#                             Name Release_Date  Rating     Views  \
# Sno.
# m0    10 things i hate about you         1999     6.9   62847.0
# m1    1492: conquest of paradise         1992     6.2   10421.0
# m2                    15 minutes         2001     6.1   25854.0
# m3         2001: a space odyssey         1968     8.4  163227.0
# m4                       48 hrs.         1982     6.9   22289.0
# ...                          ...          ...     ...       ...
# m612                    watchmen         2009     7.8  135229.0
# m613                         xxx         2002     5.6   53505.0
# m614                       x-men         2000     7.4  122149.0
# m615          young frankenstein         1974     8.0   57618.0
# m616                   zulu dawn         1979     6.4    1911.0
#
#                                                   Genes
# Sno.
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# ...

# %%
df = pd.read_csv('movie_titles_metadata.tsv' , sep = '\t', names = ['Sno.', 'Name', 'Release_Date', 'Rating', 'Views', 'Genes'])
df = df.set_index("Sno.")
df
# Out:
#                             Name Release_Date  Rating     Views  \
# Sno.
# m0    10 things i hate about you         1999     6.9   62847.0
# m1    1492: conquest of paradise         1992     6.2   10421.0
# m2                    15 minutes         2001     6.1   25854.0
# m3         2001: a space odyssey         1968     8.4  163227.0
# m4                       48 hrs.         1982     6.9   22289.0
# ...                          ...          ...     ...       ...
# m612                    watchmen         2009     7.8  135229.0
# m613                         xxx         2002     5.6   53505.0
# m614                       x-men         2000     7.4  122149.0
# m615          young frankenstein         1974     8.0   57618.0
# m616                   zulu dawn         1979     6.4    1911.0
#
#                                                   Genes
# Sno.
# m0                                 ['comedy' 'romance']
# m1          ['adventure' 'biography' 'drama' 'history']
# ...

# %% [markdown]
# <h2> 4. Header parameter </h2>
# <p>when the row sifts down or u want to make the 1st row as the header</p>

# %%
pd.read_csv('test.csv', header =1)
# Out:
#    0  enrollee_id      city  city_development_index gender  \
# 0  1        29725   city_40                   0.776   Male
# 1  2        11561   city_21                   0.624    NaN
# 2  3        33241  city_115                   0.789    NaN
# 3  4          666  city_162                   0.767   Male
#
#        relevent_experience enrolled_university education_level  \
# 0   No relevent experience       no_enrollment        Graduate
# 1   No relevent experience    Full time course        Graduate
# 2   No relevent experience                 NaN        Graduate
# 3  Has relevent experience       no_enrollment         Masters
#
#   major_discipline experience company_size    company_type last_new_job  \
# 0             STEM         15        50-99         Pvt Ltd           >4
# 1             STEM          5          NaN             NaN        never
# 2  Business Degree         <1          NaN         Pvt Ltd        never
# ...

# %% [markdown]
# <h2>5. Use_cols parameter</h2>
# use the individual columns

# %%
pd.read_csv('aug_train.csv', usecols=['enrollee_id', 'gender', 'education_level'])
# Out:
#        enrollee_id gender education_level
# 0             8949   Male        Graduate
# 1            29725   Male        Graduate
# 2            11561    NaN        Graduate
# 3            33241    NaN        Graduate
# 4              666   Male         Masters
# ...            ...    ...             ...
# 19153         7386   Male        Graduate
# 19154        31398   Male        Graduate
# 19155        24576   Male        Graduate
# 19156         5756   Male     High School
# 19157        23834    NaN  Primary School
#
# [19158 rows x 3 columns]

# %% [markdown]
# <h2> 6. Squeeze parameters </h2>

# %%
pd.read_csv('aug_train.csv', usecols = ['enrollee_id']).squeeze("columns")
# Out:
# 0         8949
# 1        29725
# 2        11561
# 3        33241
# 4          666
#          ...
# 19153     7386
# 19154    31398
# 19155    24576
# 19156     5756
# 19157    23834
# Name: enrollee_id, Length: 19158, dtype: int64

# %% [markdown]
# <h2>7. Skiprows/nrows paramters</h2>

# %% [markdown]
# pd.read_csv('aug_train.csv', skiprows =[1,5])

# %%
pd.read_csv('aug_train.csv', nrows = 100)
# Out:
#     enrollee_id      city  city_development_index gender  \
# 0          8949  city_103                   0.920   Male
# 1         29725   city_40                   0.776   Male
# 2         11561   city_21                   0.624    NaN
# 3         33241  city_115                   0.789    NaN
# 4           666  city_162                   0.767   Male
# ..          ...       ...                     ...    ...
# 95        12081   city_65                   0.802   Male
# 96         7364  city_160                   0.920    NaN
# 97        11184   city_74                   0.579    NaN
# 98         7016   city_65                   0.802   Male
# 99         8695   city_11                   0.550   Male
#
#         relevent_experience enrolled_university education_level  \
# 0   Has relevent experience       no_enrollment        Graduate
# 1    No relevent experience       no_enrollment        Graduate
# 2    No relevent experience    Full time course        Graduate
# ...

# %% [markdown]
# <h2>8. Encoding parameter</h2>

# %%
pip install chardet
# Out:
# ...
#    ---------------------------------------- 0.0/944.2 kB ? eta -:--:--
#    ----------- ---------------------------- 262.1/944.2 kB ? eta -:--:--
#    ---------------------------------------- 944.2/944.2 kB 6.4 MB/s  0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Cache entry deserialization failed, entry ignored

# %%
import chardet
with open("aug_train.csv", "rb") as f:
    result = chardet.detect(f.read())
print(result)
# Out:
# {'encoding': 'ascii', 'confidence': 1.0, 'language': 'nl', 'mime_type': 'text/plain'}

# %%
# if u get an error UnicodeDecodeError then just check the encoing of the file and in read_csv add encoding = 'language'

# %% [markdown]
# <h2>9. Skip bad lines</h2>

# %%
pd.read_csv('aug_train.csv', error_bad_lines = False)

# %%
pd.read_csv('aug_train.csv', dtype = {'target' : int}).info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19158 entries, 0 to 19157
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   enrollee_id             19158 non-null  int64
#  1   city                    19158 non-null  str
#  2   city_development_index  19158 non-null  float64
#  3   gender                  14650 non-null  str
#  4   relevent_experience     19158 non-null  str
#  5   enrolled_university     18772 non-null  str
#  6   education_level         18698 non-null  str
#  7   major_discipline        16345 non-null  str
#  8   experience              19093 non-null  str
#  9   company_size            13220 non-null  str
#  10  company_type            13018 non-null  str
#  11  last_new_job            18735 non-null  str
#  12  training_hours          19158 non-null  int64
#  13  target                  19158 non-null  int64
# dtypes: float64(1), int64(3), str(10)
# memory usage: 2.0 MB

# %% [markdown]
# <h2>10. Handling Dates</h2>
# Here dates are termed as objects or strings and we can't apply operations so to term dates as a date only not a string we use

# %%
pd.read_csv('IPL Matches 2008-2020.csv' , parse_dates= ['date']).info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 816 entries, 0 to 815
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               816 non-null    int64
#  1   city             803 non-null    str
#  2   date             816 non-null    datetime64[us]
#  3   player_of_match  812 non-null    str
#  4   venue            816 non-null    str
#  5   neutral_venue    816 non-null    int64
#  6   team1            816 non-null    str
#  7   team2            816 non-null    str
#  8   toss_winner      816 non-null    str
#  9   toss_decision    816 non-null    str
#  10  winner           812 non-null    str
#  11  result           812 non-null    str
#  12  result_margin    799 non-null    float64
#  13  eliminator       812 non-null    str
#  14  method           19 non-null     str
#  15  umpire1          816 non-null    str
#  16  umpire2          816 non-null    str
# ...

# %% [markdown]
# <h2>11. Converters</h2>

# %%
def rename(name):
    if name == "Royal Challengers Bangalore":
        return "RCB"
    else:
        return name

# %%
pd.read_csv('IPL Matches 2008-2020.csv' ,converters = {'team1' : rename})
# Out:
#           id        city        date player_of_match  \
# 0     335982   Bangalore  2008-04-18     BB McCullum
# 1     335983  Chandigarh  2008-04-19      MEK Hussey
# 2     335984       Delhi  2008-04-19     MF Maharoof
# 3     335985      Mumbai  2008-04-20      MV Boucher
# 4     335986     Kolkata  2008-04-20       DJ Hussey
# ..       ...         ...         ...             ...
# 811  1216547       Dubai  2020-09-28  AB de Villiers
# 812  1237177       Dubai  2020-11-05       JJ Bumrah
# 813  1237178   Abu Dhabi  2020-11-06   KS Williamson
# 814  1237180   Abu Dhabi  2020-11-08      MP Stoinis
# 815  1237181       Dubai  2020-11-10        TA Boult
#
#                                           venue  neutral_venue  \
# 0                         M Chinnaswamy Stadium              0
# 1    Punjab Cricket Association Stadium, Mohali              0
# 2                              Feroz Shah Kotla              0
# 3                              Wankhede Stadium              0
# ...

# %% [markdown]
# <h2>Loading a huge dataset in chunks</h2>

# %%
pd.read_csv('aug_train.csv')
# Out:
#        enrollee_id      city  city_development_index gender  \
# 0             8949  city_103                   0.920   Male
# 1            29725   city_40                   0.776   Male
# 2            11561   city_21                   0.624    NaN
# 3            33241  city_115                   0.789    NaN
# 4              666  city_162                   0.767   Male
# ...            ...       ...                     ...    ...
# 19153         7386  city_173                   0.878   Male
# 19154        31398  city_103                   0.920   Male
# 19155        24576  city_103                   0.920   Male
# 19156         5756   city_65                   0.802   Male
# 19157        23834   city_67                   0.855    NaN
#
#            relevent_experience enrolled_university education_level  \
# 0      Has relevent experience       no_enrollment        Graduate
# 1       No relevent experience       no_enrollment        Graduate
# ...

# %%
df = pd.read_csv('aug_train.csv', chunksize= 5000)
df

# %%
first_chunk = next(df)
first_chunk.head()
# Out:
#        enrollee_id      city  city_development_index gender  \
# 10000        23427   city_24                   0.698    NaN
# 10001        17605   city_50                   0.896    NaN
# 10002        20912   city_73                   0.754    NaN
# 10003        13948  city_114                   0.926   Male
# 10004        15205  city_160                   0.920   Male
#
#           relevent_experience enrolled_university education_level  \
# 10000  No relevent experience                 NaN     High School
# 10001  No relevent experience       no_enrollment        Graduate
# 10002  No relevent experience    Full time course        Graduate
# 10003  No relevent experience       no_enrollment             Phd
# 10004  No relevent experience    Full time course     High School
#
#       major_discipline experience company_size company_type last_new_job  \
# 10000              NaN          8          NaN          NaN        never
# ...

# %%
for chunk in df:
    print(chunk.shape)
# Out:
# (5000, 14)
# (5000, 14)
# (4158, 14)
